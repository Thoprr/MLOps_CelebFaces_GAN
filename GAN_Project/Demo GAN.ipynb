# %% [markdown]
# # Import Packages (DDD)

# %%
from infrastructure import data_load_transform
from domain import train_gan
from application import run_app, create_gif, monitoring

# %% [markdown]
# # Load and Transform Data

# %%
data_load_transform(n_image=10, n_jobs=-1)

# %% [markdown]
# # Training GAN

# %% [markdown]
# ### Training from 0

# %%
train_gan(epochs=5, batch_size=32)

# %% [markdown]
# ### Training from epoch n

# %%
train_gan(epochs=5, batch_size=32, resume_epoch=5)

# %% [markdown]
# # Application

# %% [markdown]
# ### Monitoring last logs

# %%
monitoring()
# Out:
# Stats:
#        Epoch_Duration  Gen_Loss_Avg  Disc_Loss_Avg
# mean       13.310000      0.780160       0.576280
# std         1.722498      0.388652       0.126122
# min        10.780000      0.257500       0.424700
# max        15.200000      1.253200       0.769600

# %% [markdown]
# ### Monitoring from logs file

# %%
monitoring("log_20241220_222321.csv")
# Out:
# Stats:
#        Epoch_Duration  Gen_Loss_Avg  Disc_Loss_Avg
# mean       16.826000      0.993920       0.840560
# std         3.671911      0.287908       0.136691
# min        13.090000      0.668900       0.623700
# max        22.750000      1.363800       0.962400

# %% [markdown]
# ### Create GIF from traning generated images

# %%
create_gif("../generated_images.gif", duration = 300)
# Out:
# GIF généré avec succès : ../generated_images.gif

# %% [markdown]
# ### Run API with last generator (http://127.0.0.1:8000/image)

# %%
run_app()

# %% [markdown]
# ### Run API with specific generator (http://127.0.0.1:8000/image)

# %%
run_app("generator_epoch_1440.keras")
